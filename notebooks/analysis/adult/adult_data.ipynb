# %%
from src.read.processing import Processing

data_loader = Processing()
data_loader.read("adult")
# Out:
#         age     workclass    fnlwgt     education  education-num  \
# 0      25.0       Private  226802.0          11th            7.0
# 1      38.0       Private   89814.0       HS-grad            9.0
# 2      28.0     Local-gov  336951.0    Assoc-acdm           12.0
# 3      44.0       Private  160323.0  Some-college           10.0
# 4      18.0             ?  103497.0  Some-college           10.0
# ...     ...           ...       ...           ...            ...
# 48837  27.0       Private  257302.0    Assoc-acdm           12.0
# 48838  40.0       Private  154374.0       HS-grad            9.0
# 48839  58.0       Private  151910.0       HS-grad            9.0
# 48840  22.0       Private  201490.0       HS-grad            9.0
# 48841  52.0  Self-emp-inc  287927.0       HS-grad            9.0
#
#            marital-status         occupation relationship   race     sex  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data_loader.df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class'],
#       dtype='object')

# %%
data_loader.general_preprocessing()
data_loader.df
# Out:
#          fnlwgt  capital-gain  capital-loss  hours-per-week  occupation  \
# 0      0.351675     -0.144804     -0.217127       -0.034087           7
# 1     -0.945524     -0.144804     -0.217127        0.772930           5
# 2      1.394723     -0.144804     -0.217127       -0.034087          11
# 3     -0.277844      0.886874     -0.217127       -0.034087           7
# 4     -0.815954     -0.144804     -0.217127       -0.841104           0
# ...         ...           ...           ...             ...         ...
# 48837  0.640492     -0.144804     -0.217127       -0.195490          13
# 48838 -0.334178     -0.144804     -0.217127       -0.034087           7
# 48839 -0.357510     -0.144804     -0.217127       -0.034087           1
# 48840  0.111984     -0.144804     -0.217127       -1.648120           1
# 48841  0.930494      1.871315     -0.217127       -0.034087           4
#
#        native-country  class  age  education-num  workclass_Federal-gov  ...  \
# ...

# %%
data_loader.df.shape
# Out:
# (48842, 27)
