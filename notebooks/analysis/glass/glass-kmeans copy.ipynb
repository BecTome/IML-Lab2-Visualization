# %% [markdown]
# # KModes Model

# %%
import pandas as pd
from src.trainflow.TrainFlow import TrainFlow
from src.clustering.KMeans import KModes

ds_name = "glass"
model = KModes
target = "Type"
ls_metrics = ['adjusted_rand_score', 'v_measure_score', 
                'silhouette_score', 'calinski_harabasz_score']

tf = TrainFlow(ds_name, model, target=target, metrics=ls_metrics)
tf.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12700\10286115.py in <module>
#       1 import pandas as pd
# ----> 2 from src.trainflow.TrainFlow import TrainFlow
#       3 from src.clustering.KMeans import KModes
#       4
#       5 ds_name = "glass"
#
# c:\Users\xavier\Desktop\UPC-MAI\IML\IML-Lab1-Clustering\src\trainflow\TrainFlow.py in <module>
# ----> 1 from src.read.processing import Processing
#       2 from src.evaluation.evaluator import Evaluator
#       3 import config
#       4 import os
#       5 import datetime
#
# c:\Users\xavier\Desktop\UPC-MAI\IML\IML-Lab1-Clustering\src\read\processing.py in <module>
#       3 import os
#       4 import logging
# ----> 5 from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, normalize,\
#       6                                     MinMaxScaler
#       7 from sklearn.impute import SimpleImputer
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
d_labels = {0: 'build_wind_float',
            1: 'vehic_wind_float',
            2: 'tableware',
            3: 'build_wind_non-float',
            4: 'headlamps',
            5: 'containers'
            }
tf.evaluator.plot_scatter_pca_visualization(tf.trained_model.labels_, 
                                            d_classes = d_labels)
# Out:
# (<Figure size 1500x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'True Classes'}, xlabel='PC1', ylabel='PC2'>,
#         <AxesSubplot:title={'center':'Clustered Classes'}, xlabel='PC1', ylabel='PC2'>],
#        dtype=object))

# %%
tf.evaluator.plot_pca()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:title={'center':'Principal Component Analysis'}, xlabel='PCA Features', ylabel='Variance %'>)

# %%
tf.df_results
# Out:
#     k  n_out_clusters  n_in_classes  adjusted_rand_score  homogeneity_score  \
# 6   5               5             6             0.256667           0.352902
# 5   4               4             6             0.240549           0.306627
# 4   4               4             6             0.237468           0.306385
# 7   5               5             6             0.214158           0.306049
# 2   3               3             6             0.211031           0.239054
# 14  9               9             6             0.201134           0.411169
# 1   2               2             6             0.199133           0.202927
# 3   3               3             6             0.198499           0.239290
# 0   2               2             6             0.192958           0.199117
# 11  7               7             6             0.181662           0.361473
# 15  9               9             6             0.177873           0.404349
# 8   6               6             6             0.174560           0.309638
# 10  7               7             6             0.164981           0.313030
# 9   6               6             6             0.163394           0.297479
# 13  8               8             6             0.148402           0.374228
# 12  8               8             6             0.126149           0.326040
#
#     completeness_score  v_measure_score  silhouette_score  \
# 6             0.445860         0.393972          0.473784
# 5             0.424021         0.355893          0.470655
# 4             0.425214         0.356149          0.363292
# 7             0.388511         0.342385          0.470979
# 2             0.406652         0.301102          0.407197
# 14            0.348610         0.377314          0.444315
# 1             0.699279         0.314569          0.427404
# 3             0.591164         0.340681          0.484029
# 0             0.698709         0.309915          0.447298
# 11            0.336565         0.348575          0.455132
# 15            0.326008         0.360977          0.488209
# 8             0.287019         0.297900          0.406163
# 10            0.314804         0.313915          0.429024
# 9             0.317511         0.307169          0.460670
# 13            0.300804         0.333523          0.460047
# 12            0.265520         0.292684          0.470801
#
#     calinski_harabasz_score
# 6                 79.898501
# 5                 89.401153
# 4                 76.515620
# 7                 81.357656
# 2                 81.207299
# 14                90.043799
# 1                 68.424140
# 3                 76.742221
# 0                 68.843430
# 11                94.260617
# 15               100.055094
# 8                 74.559491
# 10                81.058078
# 9                 96.865178
# 13               115.144760
# 12               108.712159

# %%
tf.df_results.head()
# Out:
#    k  n_out_clusters  n_in_classes  adjusted_rand_score  homogeneity_score  \
# 6  5               5             6             0.256667           0.352902
# 5  4               4             6             0.240549           0.306627
# 4  4               4             6             0.237468           0.306385
# 7  5               5             6             0.214158           0.306049
# 2  3               3             6             0.211031           0.239054
#
#    completeness_score  v_measure_score  silhouette_score  \
# 6            0.445860         0.393972          0.473784
# 5            0.424021         0.355893          0.470655
# 4            0.425214         0.356149          0.363292
# 7            0.388511         0.342385          0.470979
# 2            0.406652         0.301102          0.407197
#
#    calinski_harabasz_score
# 6                79.898501
# 5                89.401153
# 4                76.515620
# 7                81.357656
# 2                81.207299

# %%
import matplotlib.pyplot as plt

# %%
d_hyper = {'k': 0.9}

tf_euclidean = TrainFlow(ds_name=ds_name, model=model, hyperparams=d_hyper, 
                      target=target, metrics=ls_metrics)
tf_euclidean.run()

tf_euclidean.evaluator.plot_scatter_pca_visualization(tf_euclidean.trained_model.labels_, 
                                                   d_classes=d_labels)
plt.savefig('glass_dbscan_euclidean.jpg')
