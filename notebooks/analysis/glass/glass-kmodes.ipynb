# %% [markdown]
# # KModes Model

# %%
import pandas as pd
from src.trainflow.TrainFlow import TrainFlow
from src.clustering.KModes import KModes

ds_name = "glass"
model = KModes
target = "Type"
ls_metrics = ['adjusted_rand_score', 'v_measure_score', 
                'silhouette_score', 'calinski_harabasz_score']

output_path = 'report'
d_labels = {0: 'build_wind_float',
            1: 'vehic_wind_float',
            2: 'tableware',
            3: 'build_wind_non-float',
            4: 'headlamps',
            5: 'containers'
            }

tf = TrainFlow(ds_name, model, target=target, metrics=ls_metrics, 
               d_plot_params=d_labels, output_path=output_path)
tf.run()
# Out:
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Loading data
# ==================================================
#
# WARNING:root:Columns ['K'] are not in the dataset
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# INFO:src.utils.logger:Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# INFO:src.utils.logger:Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Tuning hyperparameters
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# INFO:src.utils.logger:Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# INFO:src.utils.logger:Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Writing the results
# ==================================================
# [{'k': 2}, {'k': 3}, {'k': 4}, {'k': 5}, {'k': 6}, {'k': 7}, {'k': 8}, {'k': 9}]
# {'k': 2}
# {'k': 3}
# {'k': 4}
# {'k': 5}
# {'k': 6}
# {'k': 7}
# {'k': 8}
# {'k': 9}
# ['adjusted_rand_score', 'v_measure_score', 'silhouette_score', 'calinski_harabasz_score']
# 20:09:17 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:17 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:17 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:17 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:17 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# INFO:src.utils.logger:Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Done!
# ==================================================

# %%
tf.evaluator.plot_scatter_pca_visualization(tf.trained_model.labels_, 
                                            d_classes = d_labels)
# Out:
# (<Figure size 1500x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'True Classes'}, xlabel='PC1', ylabel='PC2'>,
#         <AxesSubplot:title={'center':'Clustered Classes'}, xlabel='PC1', ylabel='PC2'>],
#        dtype=object))

# %%
tf.df_results
# Out:
#    k  n_out_clusters  n_in_classes  adjusted_rand_score  v_measure_score  \
# 5  7               7             6             0.006225         0.152082
# 0  2               2             6            -0.003973         0.024526
# 6  8               8             6            -0.009426         0.154550
# 7  9               9             6            -0.010970         0.156789
# 1  3               3             6            -0.017358         0.040644
# 2  4               4             6            -0.020277         0.049394
# 3  5               5             6            -0.024397         0.060878
# 4  6               6             6            -0.029989         0.077064
#
#    homogeneity_score  completeness_score  silhouette_score  \
# 5           0.120573            0.205884         -0.075112
# 0           0.013164            0.179146         -0.123983
# 6           0.130240            0.190019         -0.061464
# 7           0.137537            0.182308         -0.053663
# 1           0.023745            0.140974         -0.126018
# 2           0.030649            0.127167         -0.122523
# 3           0.041223            0.116360         -0.115268
# 4           0.056131            0.122895         -0.116673
#
#    calinski_harabasz_score
# 5                18.454052
# 0                 0.886371
# 6                21.416745
# 7                23.289356
# 1                 2.844335
# 2                 3.860290
# 3                 7.121811
# 4                10.104492

# %%
import matplotlib.pyplot as plt

# %%
d_hyper = {'k': 7}

new_model = KModes

tf_bp = TrainFlow(ds_name, new_model, hyperparams=d_hyper, target=target, metrics=ls_metrics, 
               d_plot_params=d_labels, output_path=output_path)
tf_bp.run()
# Out:
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Loading data
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Loading data
# ==================================================
#
# WARNING:root:Columns ['K'] are not in the dataset
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Data loaded: glass
# INFO:src.utils.logger:Data loaded: glass
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO - Running KModes on glass dataset
# INFO:src.utils.logger:Running KModes on glass dataset
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Training model
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Training model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO - Trained with: {'k': 7}
# INFO:src.utils.logger:Trained with: {'k': 7}
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Evaluating the model
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Evaluating the model
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO - Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# INFO:src.utils.logger:Scores: {'k': 7, 'n_out_clusters': 7, 'n_in_classes': 6, 'adjusted_rand_score': 0.006225414505594083, 'v_measure_score': 0.15208197929441516, 'homogeneity_score': 0.12057334510661386, 'completeness_score': 0.20588438209469567, 'silhouette_score': -0.07511207036867988, 'calinski_harabasz_score': 18.454051676829515}
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:17 - src.utils.logger - INFO -
# ==================================================
# Writing the results
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Writing the results
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO - Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# INFO:src.utils.logger:Results written in report/glass/KModes/k_7/23-10-2023_20h-09m-17s
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# 20:09:18 - src.utils.logger - INFO -
# ==================================================
# Done!
# ==================================================
#
# INFO:src.utils.logger:
# ==================================================
# Done!
# ==================================================
